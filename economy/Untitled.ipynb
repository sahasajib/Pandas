# %%
pip install fredapi > /dev/null
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from fredapi import Fred

fred_key = 'f2c58f219c8bdc626e3b765eb23b5ad3'
fred = Fred(api_key=fred_key)

# %%
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 500)
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.style.use('fivethirtyeight')
# ----> 2 pd.set_option('max_columns', 500)
#       3 color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_config/config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_config/config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# ...

# %%
sp_search = fred.search('S&P', order_by='popularity')

# %%
sp_search.shape
# Out:
# (1000, 15)

# %%
sp_search.head()
# Out:
#                             id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2      BAMLH0A0HYM2     2024-05-17   2024-05-17
# CSUSHPINSA          CSUSHPINSA     2024-05-17   2024-05-17
# SP500                    SP500     2024-05-17   2024-05-17
# MEHOINUSA672N    MEHOINUSA672N     2024-05-17   2024-05-17
# BAMLH0A0HYM2EY  BAMLH0A0HYM2EY     2024-05-17   2024-05-17
#
#                                                             title  \
# series id
# BAMLH0A0HYM2    ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA      S&P CoreLogic Case-Shiller U.S. National Home ...
# SP500                                                     S&P 500
# MEHOINUSA672N   Real Median Household Income in the United States
# BAMLH0A0HYM2EY       ICE BofA US High Yield Index Effective Yield
#
#                observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2          1996-12-31      2024-05-15  Daily, Close
# ...

# %%
#Pull Raw Data

# %%
sp500 = fred.get_series(series_id='SP500')

# %%
sp500.plot(figsize=(10, 5), title="S&P 500")
# Out:
# <Axes: title={'center': 'S&P 500'}>

# %%
#pull and multiple data series

# %%
unmp_results = fred.search('unemployment')

# %%
unmp_results.head()
# Out:
#                   id realtime_start realtime_end  \
# series id
# UNRATE        UNRATE     2024-05-17   2024-05-17
# UNRATENSA  UNRATENSA     2024-05-17   2024-05-17
# UNEMPLOY    UNEMPLOY     2024-05-17   2024-05-17
# NROU            NROU     2024-05-17   2024-05-17
# CCSA            CCSA     2024-05-17   2024-05-17
#
#                                              title observation_start  \
# series id
# UNRATE                           Unemployment Rate        1948-01-01
# UNRATENSA                        Unemployment Rate        1948-01-01
# UNEMPLOY                        Unemployment Level        1948-01-01
# NROU              Noncyclical Rate of Unemployment        1949-01-01
# CCSA       Continued Claims (Insured Unemployment)        1967-01-07
#
#           observation_end                frequency frequency_short  \
# series id
# UNRATE         2024-04-01                  Monthly               M
# UNRATENSA      2024-04-01                  Monthly               M
# ...

# %%
unrate = fred.get_series('UNRATE')

# %%
# Out:
# <Axes: >

# %%
unemp_df = fred.search('unemployment rate state', filter= ('frequency', 'Monthly'))
unemp_df = unemp_df.query('seasonal_adjustment == "Seasonally Adjusted" and units == "Percent"')
unemp_df = unemp_df.loc[unemp_df['title'].str.contains('Unemployment Rate')]

# %%
unemp_df
# Out:
#                                 id realtime_start realtime_end  \
# series id
# UNRATE                      UNRATE     2024-05-17   2024-05-17
# LNS14000006            LNS14000006     2024-05-17   2024-05-17
# CAUR                          CAUR     2024-05-17   2024-05-17
# TXUR                          TXUR     2024-05-17   2024-05-17
# M0892AUSM156SNBR  M0892AUSM156SNBR     2024-05-17   2024-05-17
# ...                            ...            ...          ...
# LNS14000048            LNS14000048     2024-05-17   2024-05-17
# LNS14000089            LNS14000089     2024-05-17   2024-05-17
# M08311USM156SNBR  M08311USM156SNBR     2024-05-17   2024-05-17
# LNS14000150            LNS14000150     2024-05-17   2024-05-17
# LRUN25TTUSM156S    LRUN25TTUSM156S     2024-05-17   2024-05-17
#
#                                                               title  \
# series id
# UNRATE                                            Unemployment Rate
# ...

# %%
unemp_df.index
# Out:
# Index(['UNRATE', 'LNS14000006', 'CAUR', 'TXUR', 'M0892AUSM156SNBR',
#        'LNS14000024', 'LNS14000031', 'M0892BUSM156SNBR', 'NYUR', 'U2RATE',
#        'FLUR', 'LNS14000002', 'LNS14000009', 'LNS14000003', 'PAUR', 'OHUR',
#        'LNS14000001', 'LNS14027660', 'MIUR', 'LNS14027662', 'ALUR',
#        'LNS14024887', 'MAUR', 'NCUR', 'ILUR', 'NJUR', 'GAUR', 'COUR', 'AZUR',
#        'WIUR', 'VAUR', 'KYUR', 'LRUN64TTUSM156S', 'SCUR', 'NMUR', 'MNUR',
#        'TNUR', 'LNS14032183', 'LNS14000012', 'WAUR', 'LNS14027659', 'MDUR',
#        'ORUR', 'WVUR', 'NVUR', 'ARUR', 'OKUR', 'MOUR', 'AKUR', 'IAUR', 'UTUR',
#        'PRUR', 'INUR', 'LAUR', 'HIUR', 'LASMT261982000000003', 'NDUR', 'MTUR',
#        'DCUR', 'MSUR', 'LNS14000060', 'LNS14000028', 'MEUR', 'NEUR',
#        'LASMT391746000000003', 'CTUR', 'IDUR', 'NHUR', 'LNS14000018', 'RIUR',
#        'KSUR', 'WYUR', 'DEUR', 'LNS14000036', 'VTUR', 'LNS14000032', 'SDUR',
#        'CMWRUR', 'LNS14200000', 'LRUN24TTUSM156S', 'LNS14027689',
# ...

# %%
unemp_df
# Out:
#                                 id realtime_start realtime_end  \
# series id
# UNRATE                      UNRATE     2024-05-17   2024-05-17
# LNS14000006            LNS14000006     2024-05-17   2024-05-17
# CAUR                          CAUR     2024-05-17   2024-05-17
# TXUR                          TXUR     2024-05-17   2024-05-17
# M0892AUSM156SNBR  M0892AUSM156SNBR     2024-05-17   2024-05-17
# ...                            ...            ...          ...
# LNS14000048            LNS14000048     2024-05-17   2024-05-17
# LNS14000089            LNS14000089     2024-05-17   2024-05-17
# M08311USM156SNBR  M08311USM156SNBR     2024-05-17   2024-05-17
# LNS14000150            LNS14000150     2024-05-17   2024-05-17
# LRUN25TTUSM156S    LRUN25TTUSM156S     2024-05-17   2024-05-17
#
#                                                               title  \
# series id
# UNRATE                                            Unemployment Rate
# ...

# %%
all_results = []
for myid in unemp_df .index:
    results = fred.get_series(myid)
    results = results.to_frame(name=myid)
    all_results.append(results)
uemp_results = pd.concat(all_results, axis=1).drop(['M0892AUSM156SNBR', 'DSUR'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 6
#       4     results = results.to_frame(name=myid)
#       5     all_results.append(results)
# ----> 6 uemp_results = pd.concat(all_results, axis=1).drop(['M0892AUSM156SNBR', 'DSUR'], axis=1)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
all_results[20]
# Out:
#             ALUR
# 1976-01-01   6.6
# 1976-02-01   6.6
# 1976-03-01   6.6
# 1976-04-01   6.5
# 1976-05-01   6.4
# ...          ...
# 2023-11-01   2.8
# 2023-12-01   2.8
# 2024-01-01   2.9
# 2024-02-01   3.0
# 2024-03-01   3.0
#
# [579 rows x 1 columns]

# %%
uemp_states = uemp_results.drop('UNRATE', axis=1)

# %%
unrate.plot()
# Out:
# <Axes: >

# %%
unemp_status = u
